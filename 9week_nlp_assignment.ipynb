# %% [markdown]
# # 9week

# %%
# !pip install konlpy
import numpy as np
import pandas as pd 
from konlpy.tag import *
from gensim.models import Word2Vec, fasttext

# %%
twitter = Okt()  #twitter class 객체당!
komoran = Komoran()
kkma = Kkma()
# mecab = Mecab()
# hannanum = Hannanum()

# %% [markdown]
# # nct - 백야 노래

# %%
text = '조용히 어두워지고 금방 비가 올 듯해 여전히 먹먹한 이런 날씨가 너는 좋은지 잘 지내? 묻지 못해 난 왜 잊지 못하고 낮과 밤이 온통 너인데 ooh 아직도 난 이렇게 지내 알잖아 조금 이해해줘 날 오늘도 난 여기서 또 잠 못 든 채 너를 잊어가 혼자만의 긴 안녕 잠 못 드는 오늘도 All night long 참 길어져 버린 이별에 우습게 보일 나지만 인사를 건네 안녕 오늘도 오늘도 all night long 차라리 이 모든 게 다 꿈이라면 좋겠어 난 이미 꿈보다 꿈같은 곳에 살아 yeah Your face, your skin, your voice 지울 수가 없을까 자꾸만 더 선명해져 가 ooh 아직도 난 이렇게 지내 잠들지 못한 기억을 혼자 걷다가 널 찾다가 또 뜬 눈으로 밤을 새우지 혼자만의 긴 안녕 잠 못 드는 오늘도 All night long 참 길어져 버린 이별에 우습게 보일 나지만 인사를 건네 안녕 억지로 잠을 청해보다 스친 꿈에도 너를 만나 전부 너란 시간 속에 오늘도 새하얀 밤 Oh 너를 그려 all night long 내쉬는 숨 네 목소리 들려와 난 아직 너를 꿈꾸다 All night long ya 나의 꿈 나의 꿈은 아직 너야 yeah yeah 안녕 all night long'

# %% [markdown]
# # 명사 추출

# %%
#twitter(Okt)
twitter.nouns(text)
# Out:
# ['금방',
#  '비',
#  '듯',
#  '날씨',
#  '너',
#  '난',
#  '왜',
#  '못',
#  '낮',
#  '밤',
#  '온통',
#  '너',
#  '난',
#  '조금',
#  '이해',
#  '날',
#  '오늘',
#  '난',
#  '여기',
#  '또',
#  '잠',
#  '못',
#  '채',
#  '너',
#  '혼자',
#  '안녕',
#  '잠',
#  '못',
#  '오늘',
#  '이별',
#  '나',
#  '인사',
#  '안녕',
#  '오늘',
#  '오늘',
#  '차라리',
#  '이',
#  '모든',
#  '게',
#  '난',
#  '꿈',
#  '꿈',
#  '곳',
#  '살',
#  '수가',
#  '자꾸만',
#  '더',
#  '난',
#  '못',
#  '기억',
#  '혼자',
#  '널',
#  '또',
#  '눈',
#  '밤',
#  '혼자',
#  '안녕',
#  '잠',
#  '못',
#  '오늘',
#  '이별',
#  '나',
#  '인사',
#  '안녕',
#  '억지로',
#  '잠',
#  '청해',
#  '꿈',
#  '너',
#  '전부',
#  '란',
#  '시간',
#  '속',
#  '오늘',
#  '새',
#  '밤',
#  '너',
#  '숨',
#  '네',
#  '목소리',
#  '난',
#  '너',
#  '나',
#  '꿈',
#  '나',
#  '꿈',
#  '너',
#  '안녕']

# %%
#komoran
komoran.nouns(text)
# Out:
# ['비',
#  '듯',
#  '날씨',
#  '낮과 밤',
#  '이해',
#  '날',
#  '오늘',
#  '잠',
#  '채',
#  '혼자',
#  '안녕',
#  '잠',
#  '오늘',
#  '이별',
#  '인사',
#  '안녕',
#  '오늘',
#  '오늘',
#  '게',
#  '꿈',
#  '꿈',
#  '곳',
#  '수',
#  '기억',
#  '혼자',
#  '눈',
#  '밤',
#  '혼자',
#  '안녕',
#  '잠',
#  '오늘',
#  '이별',
#  '인사',
#  '안녕',
#  '잠',
#  '청해',
#  '꿈',
#  '시간',
#  '속',
#  '오늘',
#  '밤',
#  '숨',
#  '목소리',
#  '꿈',
#  '꿈',
#  '안녕']

# %%
#kkma
kkma.nouns(text)
# Out:
# ['비',
#  '날씨',
#  '너',
#  '나',
#  '낮',
#  '밤',
#  '이해',
#  '날',
#  '오늘',
#  '여기',
#  '잠',
#  '채',
#  '혼자',
#  '안녕',
#  '이별',
#  '나지',
#  '인사',
#  '꿈',
#  '곳',
#  '수',
#  '선명',
#  '기억',
#  '널',
#  '눈',
#  '시간',
#  '속',
#  '숨',
#  '목소리',
#  '나의']

# %% [markdown]
# # 형태소 추출

# %%
#twitter(Okt)
twitter.morphs(text)
# Out:
# ['조용히',
#  '어두워지고',
#  '금방',
#  '비',
#  '가',
#  '올',
#  '듯',
#  '해',
#  '여전히',
#  '먹',
#  '먹한',
#  '이런',
#  '날씨',
#  '가',
#  '너',
#  '는',
#  '좋은지',
#  '잘',
#  '지내',
#  '?',
#  '묻지',
#  '못',
#  '해',
#  '난',
#  '왜',
#  '잊지',
#  '못',
#  '하고',
#  '낮',
#  '과',
#  '밤',
#  '이',
#  '온통',
#  '너',
#  '인데',
#  'ooh',
#  '아직도',
#  '난',
#  '이렇게',
#  '지내',
#  '알잖아',
#  '조금',
#  '이해',
#  '해줘',
#  '날',
#  '오늘',
#  '도',
#  '난',
#  '여기',
#  '서',
#  '또',
#  '잠',
#  '못',
#  '든',
#  '채',
#  '너',
#  '를',
#  '잊어가',
#  '혼자',
#  '만의',
#  '긴',
#  '안녕',
#  '잠',
#  '못',
#  '드는',
#  '오늘',
#  '도',
#  'All',
#  'night',
#  'long',
#  '참',
#  '길어져',
#  '버린',
#  '이별',
#  '에',
#  '우습게',
#  '보일',
#  '나',
#  '지만',
#  '인사',
#  '를',
#  '건네',
#  '안녕',
#  '오늘',
#  '도',
#  '오늘',
#  '도',
#  'all',
#  'night',
#  'long',
#  '차라리',
#  '이',
#  '모든',
#  '게',
#  '다',
#  '꿈이라면',
#  '좋겠어',
#  '난',
#  '이미',
#  '꿈',
#  '보다',
#  '꿈',
#  '같은',
#  '곳',
#  '에',
#  '살',
#  '아',
#  'yeah',
#  'Your',
#  'face',
#  ',',
#  'your',
# ...

# %%
#komoran
komoran.morphs(text)
# Out:
# ['조용히',
#  '어둡',
#  '어',
#  '지',
#  '고',
#  '금방',
#  '비',
#  '가',
#  '올',
#  '듯',
#  '하',
#  '아',
#  '여전히',
#  '먹먹',
#  '하',
#  'ㄴ',
#  '이런',
#  '날씨',
#  '가',
#  '너',
#  '는',
#  '좋',
#  '은지',
#  '잘',
#  '지내',
#  '어',
#  '?',
#  '묻',
#  '지',
#  '못하',
#  '아',
#  '나',
#  'ㄴ',
#  '왜',
#  '잊',
#  '지',
#  '못하',
#  '고',
#  '낮과 밤',
#  '이',
#  '온통',
#  '너',
#  '이',
#  'ㄴ데',
#  'ooh',
#  '아직',
#  '도',
#  '나',
#  'ㄴ',
#  '이렇',
#  '게',
#  '지내',
#  '어',
#  '알',
#  '잖아',
#  '조금',
#  '이해',
#  '하',
#  '아',
#  '주',
#  '어',
#  '날',
#  '오늘',
#  '도',
#  '나',
#  'ㄴ',
#  '여기',
#  '서',
#  '또',
#  '잠',
#  '못',
#  '들',
#  'ㄴ',
#  '채',
#  '너',
#  '를',
#  '잊',
#  '어',
#  '가',
#  '혼자',
#  '만',
#  '의',
#  '길',
#  'ㄴ',
#  '안녕',
#  '잠',
#  '못',
#  '들',
#  '는',
#  '오늘',
#  '도',
#  'All',
#  'night',
#  'long',
#  '참',
#  '길',
#  '어',
#  '지',
#  '어',
#  '버리',
#  'ㄴ',
#  '이별',
#  '에',
#  '우습',
#  '게',
#  '보이',
#  'ㄹ',
#  '나',
#  '지만',
#  '인사',
#  '를',
#  '건네',
#  '어',
#  '안녕',
#  '오늘',
#  '도',
#  '오늘',
#  '도',
# ...

# %%
#kkma
kkma.morphs(text)
# Out:
# ['조용히',
#  '어둡',
#  '어',
#  '지',
#  '고',
#  '금방',
#  '비',
#  '가',
#  '오',
#  'ㄹ',
#  '듯하',
#  '어',
#  '여전히',
#  '먹먹',
#  '하',
#  'ㄴ',
#  '이런',
#  '날씨',
#  '가',
#  '너',
#  '는',
#  '좋',
#  '은지',
#  '잘',
#  '지내',
#  '?',
#  '묻',
#  '지',
#  '못하',
#  '어',
#  '나',
#  '는',
#  '왜',
#  '잊',
#  '지',
#  '못하',
#  '고',
#  '낮',
#  '과',
#  '밤',
#  '이',
#  '온통',
#  '너',
#  '이',
#  'ㄴ데',
#  'ooh',
#  '아직',
#  '도',
#  '나',
#  '는',
#  '이렇',
#  '게',
#  '지내',
#  '알',
#  '잖아',
#  '조금',
#  '이해',
#  '하',
#  '어',
#  '주',
#  '어',
#  '날',
#  '오늘',
#  '도',
#  '나',
#  '는',
#  '여기',
#  '서',
#  '또',
#  '잠',
#  '못',
#  '들',
#  'ㄴ',
#  '채',
#  '너',
#  '를',
#  '잊',
#  '어',
#  '가',
#  '혼자',
#  '만',
#  '의',
#  '길',
#  'ㄴ',
#  '안녕',
#  '잠',
#  '못',
#  '들',
#  '는',
#  '오늘',
#  '도',
#  'All',
#  'night',
#  'long',
#  '참',
#  '긷',
#  '어',
#  '지',
#  '어',
#  '버리',
#  'ㄴ',
#  '이별',
#  '에',
#  '우습',
#  '게',
#  '보이',
#  'ㄹ',
#  '나지',
#  '만',
#  '인사',
#  '를',
#  '건네',
#  '안녕',
#  '오늘',
#  '도',
#  '오늘',
#  '도',
#  'all',
# ...

# %% [markdown]
# # 형태소 품사 태깅

# %%
#twitter(Okt)
twitter.pos(text)
# Out:
# [('조용히', 'Adjective'),
#  ('어두워지고', 'Verb'),
#  ('금방', 'Noun'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('올', 'Verb'),
#  ('듯', 'Noun'),
#  ('해', 'Verb'),
#  ('여전히', 'Adjective'),
#  ('먹', 'Verb'),
#  ('먹한', 'Verb'),
#  ('이런', 'Adjective'),
#  ('날씨', 'Noun'),
#  ('가', 'Josa'),
#  ('너', 'Noun'),
#  ('는', 'Josa'),
#  ('좋은지', 'Adjective'),
#  ('잘', 'Verb'),
#  ('지내', 'Verb'),
#  ('?', 'Punctuation'),
#  ('묻지', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('해', 'Verb'),
#  ('난', 'Noun'),
#  ('왜', 'Noun'),
#  ('잊지', 'Verb'),
#  ('못', 'Noun'),
#  ('하고', 'Josa'),
#  ('낮', 'Noun'),
#  ('과', 'Josa'),
#  ('밤', 'Noun'),
#  ('이', 'Josa'),
#  ('온통', 'Noun'),
#  ('너', 'Noun'),
#  ('인데', 'Josa'),
#  ('ooh', 'Alpha'),
#  ('아직도', 'Adverb'),
#  ('난', 'Noun'),
#  ('이렇게', 'Adverb'),
#  ('지내', 'Verb'),
#  ('알잖아', 'Verb'),
#  ('조금', 'Noun'),
#  ('이해', 'Noun'),
#  ('해줘', 'Verb'),
#  ('날', 'Noun'),
#  ('오늘', 'Noun'),
#  ('도', 'Josa'),
#  ('난', 'Noun'),
#  ('여기', 'Noun'),
#  ('서', 'Josa'),
#  ('또', 'Noun'),
# ...

# %%
#komoran
komoran.pos(text)
# Out:
# [('조용히', 'MAG'),
#  ('어둡', 'VA'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('고', 'EC'),
#  ('금방', 'MAG'),
#  ('비', 'NNG'),
#  ('가', 'JKS'),
#  ('올', 'MM'),
#  ('듯', 'NNB'),
#  ('하', 'XSA'),
#  ('아', 'EC'),
#  ('여전히', 'MAG'),
#  ('먹먹', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('이런', 'MM'),
#  ('날씨', 'NNG'),
#  ('가', 'JKS'),
#  ('너', 'NP'),
#  ('는', 'JX'),
#  ('좋', 'VA'),
#  ('은지', 'EC'),
#  ('잘', 'MAG'),
#  ('지내', 'VV'),
#  ('어', 'EF'),
#  ('?', 'SF'),
#  ('묻', 'VV'),
#  ('지', 'EC'),
#  ('못하', 'VX'),
#  ('아', 'EC'),
#  ('나', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('왜', 'MAG'),
#  ('잊', 'VV'),
#  ('지', 'EC'),
#  ('못하', 'VX'),
#  ('고', 'EC'),
#  ('낮과 밤', 'NNP'),
#  ('이', 'JKS'),
#  ('온통', 'MAG'),
#  ('너', 'NP'),
#  ('이', 'VCP'),
#  ('ㄴ데', 'EC'),
#  ('ooh', 'SL'),
#  ('아직', 'MAG'),
#  ('도', 'JX'),
#  ('나', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('이렇', 'VA'),
#  ('게', 'EC'),
#  ('지내', 'VV'),
#  ('어', 'EC'),
#  ('알', 'VV'),
#  ('잖아', 'EC'),
#  ('조금', 'MAG'),
#  ('이해', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
# ...

# %%
#kkma
kkma.pos(text)
# Out:
# [('조용히', 'MAG'),
#  ('어둡', 'VA'),
#  ('어', 'ECS'),
#  ('지', 'VXV'),
#  ('고', 'ECE'),
#  ('금방', 'MAG'),
#  ('비', 'NNG'),
#  ('가', 'JKS'),
#  ('오', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('듯하', 'VXA'),
#  ('어', 'ECS'),
#  ('여전히', 'MAG'),
#  ('먹먹', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETD'),
#  ('이런', 'MDT'),
#  ('날씨', 'NNG'),
#  ('가', 'JKS'),
#  ('너', 'NP'),
#  ('는', 'JX'),
#  ('좋', 'VA'),
#  ('은지', 'ECS'),
#  ('잘', 'MAG'),
#  ('지내', 'MAG'),
#  ('?', 'SF'),
#  ('묻', 'VV'),
#  ('지', 'ECD'),
#  ('못하', 'VX'),
#  ('어', 'ECS'),
#  ('나', 'NP'),
#  ('는', 'JX'),
#  ('왜', 'MAG'),
#  ('잊', 'VV'),
#  ('지', 'ECD'),
#  ('못하', 'VX'),
#  ('고', 'ECE'),
#  ('낮', 'NNG'),
#  ('과', 'JC'),
#  ('밤', 'NNG'),
#  ('이', 'JKS'),
#  ('온통', 'MAG'),
#  ('너', 'NP'),
#  ('이', 'VCP'),
#  ('ㄴ데', 'ECE'),
#  ('ooh', 'OL'),
#  ('아직', 'MAG'),
#  ('도', 'JX'),
#  ('나', 'NP'),
#  ('는', 'JX'),
#  ('이렇', 'VA'),
#  ('게', 'ECD'),
#  ('지내', 'MAG'),
#  ('알', 'VV'),
#  ('잖아', 'EFN'),
#  ('조금', 'MAG'),
#  ('이해', 'NNG'),
#  ('하', 'XSV'),
# ...

# %%
text = """
조용히 어두워지고 금방 비가 올 듯해
여전히 먹먹한 이런 날씨가 너는 좋은지
잘 지내? 묻지 못해
난 왜 잊지 못하고
낮과 밤이 온통 너인데
아직도 난 이렇게 지내
알잖아 조금 이해해줘 날
오늘도 난 여기서
또 잠 못 든 채 너를 잊어가
혼자만의 긴 안녕
잠 못 드는 오늘도
참 길어져 버린
이별에 우습게 보일 나지만
인사를 건네 안녕
오늘도 오늘도 
차라리
이 모든 게 다 꿈이라면 좋겠어
난 이미
꿈보다 꿈같은 곳에 살아 
지울 수가 없을까
자꾸만 더 
선명해져 가 ooh
아직도 난 이렇게 지내
잠들지 못한 기억을 혼자
걷다가 널 찾다가
또 뜬 눈으로 밤을 새우지
혼자만의 긴 안녕
잠 못 드는 오늘도
참 길어져 버린
이별에 우습게 보일 나지만
인사를 건네 안녕
억지로 잠을 청해보다
스친 꿈에도 너를 만나
전부 너란 시간 속에 오늘도
새하얀 밤
Oh 너를 그려
내쉬는 숨 
네 목소리 들려와
난 아직 
너를 꿈꾸다
ya 나의 꿈
나의 꿈은 아직 너야 yeah yeah
너를 너를 너를 그리는 그리는 이 밤
"""

# %%
#Tokenize

def make_corpus(text):
    corpus = []
    for s in text.split('\n'):
        corpus.append(['/'.join(p) for p in twitter.pos(s)])
    return corpus

# %%
# 토큰 모음집 만들기

corpus = make_corpus(text)

# %%
from gensim.models import Word2Vec, fasttext

# %%
#임베딩(w2v_skipgram)모델 생성
Skip_Gram_model = Word2Vec(corpus, size=2, window=3, min_count=1, workers=1, iter=1000, sg=1)

# %% [markdown]
# # TEST

# %%
#index2word
words = Skip_Gram_model.wv.index2word #one-hot encoding알아서 해줌 
words
# Out:
# ['너/Noun',
#  '를/Josa',
#  '난/Noun',
#  '오늘/Noun',
#  '도/Josa',
#  '못/Noun',
#  '꿈/Noun',
#  '밤/Noun',
#  '잠/Noun',
#  '안녕/Noun',
#  '에/Josa',
#  '나/Noun',
#  '지내/Verb',
#  '혼자/Noun',
#  '을/Josa',
#  '가/Josa',
#  '해/Verb',
#  '아직도/Adverb',
#  '이렇게/Adverb',
#  '또/Noun',
#  '만의/Josa',
#  '긴/Verb',
#  '드는/Verb',
#  '참/Verb',
#  '길어져/Verb',
#  '버린/Verb',
#  '이별/Noun',
#  '우습게/Verb',
#  '보일/Verb',
#  '지만/Josa',
#  '인사/Noun',
#  '건네/Verb',
#  '이/Noun',
#  '보다/Josa',
#  '아직/Adverb',
#  '의/Josa',
#  'yeah/Alpha',
#  '그리는/Verb',
#  '조용히/Adjective',
#  '어두워지고/Verb',
#  '금방/Noun',
#  '비/Noun',
#  '올/Verb',
#  '듯/Noun',
#  '여전히/Adjective',
#  '먹/Verb',
#  '먹한/Verb',
#  '이런/Adjective',
#  '날씨/Noun',
#  '는/Josa',
#  '좋은지/Adjective',
#  '잘/Verb',
#  '?/Punctuation',
#  '묻지/Verb',
#  '못/VerbPrefix',
#  '왜/Noun',
#  '잊지/Verb',
#  '하고/Josa',
#  '낮/Noun',
#  '과/Josa',
#  '이/Josa',
#  '온통/Noun',
#  '인데/Josa',
#  '알잖아/Verb',
#  '조금/Noun',
#  '이해/Noun',
#  '해줘/Verb',
#  '날/Noun',
#  '여기/Noun',
# ...

# %%
# text 토큰 임베딩 벡터
vectors = Skip_Gram_model.wv.vectors
vectors
# Out:
# array([[ 1.0957658 , -0.5041529 ],
#        [ 1.1764063 , -0.45484784],
#        [ 0.19813284, -0.8279916 ],
#        [ 0.00861818, -1.2240438 ],
#        [-0.00463258, -1.2409256 ],
#        [ 0.8571764 , -0.5760462 ],
#        [ 2.698989  , -0.43391967],
#        [ 1.653024  , -0.5894434 ],
#        [ 0.9961874 , -0.4608424 ],
#        [ 1.0939689 , -0.27157706],
#        [ 0.29642433, -0.9331553 ],
#        [ 0.7538484 , -0.4887555 ],
#        [-0.10585681, -1.67932   ],
#        [ 1.4472327 , -0.2962537 ],
#        [ 2.2901216 , -0.48019993],
#        [-0.11146379, -3.7877707 ],
#        [-0.24611826, -3.2820716 ],
#        [-0.05224088, -1.2467291 ],
#        [-0.09912433, -1.2925568 ],
#        [ 2.456597  , -0.4865822 ],
#        [ 1.2090513 , -0.25107694],
#        [ 1.2897182 , -0.1912114 ],
#        [ 0.2830898 , -0.76026696],
#        [ 0.1391185 , -0.81897014],
#        [ 0.258241  , -0.7093596 ],
#        [ 0.30122805, -0.6918776 ],
#        [ 0.22965662, -1.2154487 ],
# ...

# %%
# 토큰과 벡터 zip
Skip_Gram_model_result = dict(zip(words, vectors))

# %%
# 유사도 top5
Skip_Gram_model.most_similar('기억/Noun', topn=5)  #기억 토큰과 유사한 top5개 보기  #word2vec 코사인 유사도!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-3276fd111e30> in <module>()
# ----> 1 Skip_Gram_model.most_similar('기억/Noun', topn=5)  #기억 토큰과 유사한 top5개 보기  #word2vec 코사인 유사도!
#
# /usr/local/lib/python3.6/dist-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1420                     stacklevel=2
#    1421                 )
# -> 1422                 return func(*args, **kwargs)
#    1423
#    1424             return new_func1
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# ...

# %%
import pandas as pd

w2v_df = pd.DataFrame(vectors, columns = ['x1', 'x2'])
w2v_df['word'] = words
w2v_df = w2v_df[['word', 'x1', 'x2']]
w2v_df
# Out:
#          word        x1        x2
# 0      너/Noun  1.095766 -0.504153
# 1      를/Josa  1.176406 -0.454848
# 2      난/Noun  0.198133 -0.827992
# 3     오늘/Noun  0.008618 -1.224044
# 4      도/Josa -0.004633 -1.240926
# ..        ...       ...       ...
# 120  들려와/Verb  0.213971 -1.297642
# 121  꿈꾸다/Verb  0.927525 -0.486834
# 122  ya/Alpha  1.686405 -0.303944
# 123    은/Josa  2.924493 -0.317981
# 124    야/Josa  3.302042 -0.364228
#
# [125 rows x 3 columns]

# %%
# 일단 import 
# %matplotlib inline  

import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
# 체크해보면 폰트 개수가 늘어났다
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# sys_font number: 48
# nanum_font number: 31

# %%
nanum_font
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf',
# ...

# %%
# 현재 설정되어 있는 폰트 사이즈와 글꼴을 알아보자
# !python --version
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()
# Out:
# Python 3.6.9
# 설정 폰트 글꼴: ['sans-serif'], 설정 폰트 사이즈: 10.0

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# Out:
# NanumGothic

# %%
# 우선 fm._rebuild() 를 해주고
fm._rebuild()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

warnings.filterwarnings("ignore", category=DeprecationWarning) 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

fig, ax = plt.subplots()

for word, x1, x2 in zip(w2v_df['word'], w2v_df['x1'], w2v_df['x2']):
    ax.annotate(word, (x1,x2 ))
    
PADDING = 1.0
x_axis_min = np.amin(vectors, axis=0)[0] - PADDING
y_axis_min = np.amin(vectors, axis=0)[1] - PADDING
x_axis_max = np.amax(vectors, axis=0)[0] + PADDING
y_axis_max = np.amax(vectors, axis=0)[1] + PADDING
 
plt.xlim(x_axis_min,x_axis_max)
plt.ylim(y_axis_min,y_axis_max)
plt.rcParams["figure.figsize"] = (30,30)

plt.show()

# %% [markdown]
# # 아이유 - 이런엔딩

# %% [markdown]
# https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%95%84%EC%9D%B4%EC%9C%A0+%EC%9D%B4%EB%9F%B0%EC%97%94%EB%94%A9+%EA%B0%80%EC%82%AC

# %%
text = """
안녕 오랜만이야
물음표 없이 참 너다운 목소리
정해진 규칙처럼
추운 문가에 늘 똑같은 네 자리

제대로 잘 먹어 다 지나가니까
예전처럼 잠도 잘 자게 될 거야
진심으로 빌게
너는 더 행복할 자격이 있어

그런 말은 하지 마 제발
그 말이 더 아픈 거 알잖아
사랑해줄 거라며 다 뭐야
어떤 맘을 준 건지 너는 모를 거야

외로웠던 만큼
너를 너보다 사랑해줄 사람
꼭 만났으면 해
내가 아니라서 미안해
주는 게 쉽지가 않아

그런 말은 하지 마 제발
그 말이 더 아픈 거 알잖아
사랑해줄 거라며 다 뭐야
어떤 맘을 준 건지 끝내 모를.

솔직히 말해줄래 제발
너라면 다 믿는 거 알잖아
네 말대로 언젠가 나도
나 같은 누군가에게
사랑받게 될까?
"""

# %%
#Tokenize

def make_corpus(text):
    corpus = []
    for s in text.split('\n'):
        corpus.append(['/'.join(p) for p in twitter.pos(s)])
    return corpus

# %%
# 토큰 모음집 만들기
corpus = make_corpus(text)

# %%
# 임베딩 과정 (w2v_skipgram)모델 생성

from gensim.models import Word2Vec, fasttext

Skip_Gram_model = Word2Vec(corpus, size=2, window=3, min_count=1, workers=1, iter=1000, sg=1)

# %% [markdown]
# # Test

# %%
#index2word
words = Skip_Gram_model.wv.index2word #one-hot encoding알아서 해줌 
words
# Out:
# ['말/Noun',
#  '거/Noun',
#  '다/Adverb',
#  '너/Noun',
#  '야/Josa',
#  '더/Noun',
#  '이/Josa',
#  '제발/Noun',
#  '알잖아/Verb',
#  '사랑/Noun',
#  '해줄/Verb',
#  '너/Modifier',
#  '처럼/Josa',
#  '네/Noun',
#  '잘/Verb',
#  '거야/Eomi',
#  '는/Josa',
#  '그런/Adjective',
#  '은/Josa',
#  '하지/Verb',
#  '마/Noun',
#  '그/Noun',
#  '아픈/Adjective',
#  '라며/Noun',
#  '뭐/Noun',
#  '어떤/Adjective',
#  '맘/Noun',
#  '을/Josa',
#  '준/Noun',
#  '건지/Verb',
#  '모를/Verb',
#  '안녕/Noun',
#  '오랜/Modifier',
#  '만이/Noun',
#  '물음표/Noun',
#  '없이/Adverb',
#  '참/Verb',
#  '다운/Noun',
#  '목소리/Noun',
#  '정해진/Noun',
#  '규칙/Noun',
#  '추운/Verb',
#  '문가에/Verb',
#  '늘/Noun',
#  '똑같은/Adjective',
#  '자리/Noun',
#  '제대로/Noun',
#  '먹어/Verb',
#  '지나가니까/Verb',
#  '예전/Noun',
#  '잠도/Noun',
#  '자게/Noun',
#  '될/Verb',
#  '진심/Noun',
#  '으로/Josa',
#  '빌게/Verb',
#  '행복할/Adjective',
#  '자격/Noun',
#  '있어/Adjective',
#  '외로웠던/Adjective',
#  '만큼/Noun',
#  '를/Josa',
#  '보다/Josa',
#  '사람/Noun',
#  '꼭/Noun',
#  '만났으면/Verb',
#  '해/Noun',
#  '내/Noun',
# ...

# %%
# text 토큰 임베딩 벡터
vectors = Skip_Gram_model.wv.vectors
vectors
# Out:
# array([[-1.7652513 , -0.2498298 ],
#        [-0.79845536,  0.5286906 ],
#        [-0.75124884,  0.6596844 ],
#        [-0.6586909 ,  2.670729  ],
#        [-0.6077491 ,  1.1003073 ],
#        [-0.840974  ,  0.6054058 ],
#        [-0.8922317 ,  0.5180907 ],
#        [-2.3135989 , -0.5548485 ],
#        [-1.1268194 ,  0.2708767 ],
#        [-0.542302  ,  1.6380204 ],
#        [-0.5305438 ,  1.7091146 ],
#        [-2.3974636 , -0.27353516],
#        [-0.9412375 ,  0.83512175],
#        [-2.5812654 , -0.3172076 ],
#        [-1.1590511 ,  0.6075765 ],
#        [-0.6860062 ,  2.06368   ],
#        [-0.6207169 ,  2.2145367 ],
#        [-2.3250368 , -0.5483284 ],
#        [-2.4337032 , -0.62060106],
#        [-2.48324   , -0.6099836 ],
#        [-2.3574312 , -0.5853266 ],
#        [-1.0342803 ,  0.28903112],
#        [-1.0016273 ,  0.29498664],
#        [-0.5121226 ,  1.260033  ],
#        [-0.4951025 ,  1.2788008 ],
#        [-0.75774795,  3.3537152 ],
#        [-0.77317077,  3.3423388 ],
# ...

# %%
# 토큰과 벡터 zip
Skip_Gram_model_result = dict(zip(words, vectors))

# 유사도 top5
Skip_Gram_model.most_similar('안녕/Noun', topn=5)  #안녕 토큰과 유사한 top5개 보기  #word2vec 코사인 유사도!
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('만이/Noun', 0.9999850988388062),
#  ('정해진/Noun', 0.9999716281890869),
#  ('자게/Noun', 0.9998713731765747),
#  ('오랜/Modifier', 0.9997633695602417),
#  ('될/Verb', 0.9994635581970215)]

# %%
Skip_Gram_model.most_similar('사랑/Noun', topn=5)  #안녕 토큰과 유사한 top5개 보기  #word2vec 코사인 유사도!
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('거야/Eomi', 0.9999992251396179),
#  ('해줄/Verb', 0.9998247027397156),
#  ('는/Josa', 0.9989221096038818),
#  ('뭐/Noun', 0.998766303062439),
#  ('쉽지가/Verb', 0.9985334873199463)]

# %%
import pandas as pd

w2v_df2 = pd.DataFrame(vectors, columns = ['x1', 'x2'])
w2v_df2['word'] = words
w2v_df2 = w2v_df2[['word', 'x1', 'x2']]
w2v_df2
# Out:
#              word        x1        x2
# 0          말/Noun -1.765251 -0.249830
# 1          거/Noun -0.798455  0.528691
# 2        다/Adverb -0.751249  0.659684
# 3          너/Noun -0.658691  2.670729
# 4          야/Josa -0.607749  1.100307
# ..            ...       ...       ...
# 86       누군가/Noun -0.654470  1.382995
# 87        에게/Josa -0.700995  1.350696
# 88      사랑받게/Verb -0.957234  0.320791
# 89        될까/Verb -0.907030  0.369883
# 90  ?/Punctuation -1.042118  0.237068
#
# [91 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

warnings.filterwarnings("ignore", category=DeprecationWarning)

import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

fig, ax = plt.subplots()

for word, x1, x2 in zip(w2v_df2['word'], w2v_df2['x1'], w2v_df2['x2']):
    ax.annotate(word, (x1,x2 ))
    
PADDING = 1.0
x_axis_min = np.amin(vectors, axis=0)[0] - PADDING
y_axis_min = np.amin(vectors, axis=0)[1] - PADDING
x_axis_max = np.amax(vectors, axis=0)[0] + PADDING
y_axis_max = np.amax(vectors, axis=0)[1] + PADDING
 
plt.xlim(x_axis_min,x_axis_max)
plt.ylim(y_axis_min,y_axis_max)
plt.rcParams["figure.figsize"] = (10,10)

plt.show()

# %% [markdown]
# 출처
#
# 코랩에서 한글 폰트 사용하기 : https://colab.research.google.com/github/nicewook/datascience_exercise/blob/master/korean_font_on_matplotlib.ipynb (폰트 에러 시 런타임 다시 실행)
#
# 패스트 캠퍼스 : https://github.com/lovit/python_ml4nlp/blob/master/day5_embedding_and_visualizing/day_5_4_fasttext_gensim.ipynb
